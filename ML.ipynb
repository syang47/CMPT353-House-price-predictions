# %%
import pandas as pd
import numpy as np
from math import radians, cos, sin, asin, sqrt

# %%
listings_data = pd.read_csv('listings.csv.gz')

# %%
listings_data
# Out:
#             id                            listing_url       scrape_id  \
# 0        10080     https://www.airbnb.com/rooms/10080  20210412154228
# 1        13358     https://www.airbnb.com/rooms/13358  20210412154228
# 2        13490     https://www.airbnb.com/rooms/13490  20210412154228
# 3        14267     https://www.airbnb.com/rooms/14267  20210412154228
# 4        16254     https://www.airbnb.com/rooms/16254  20210412154228
# ...        ...                                    ...             ...
# 4294  49132295  https://www.airbnb.com/rooms/49132295  20210412154228
# 4295  49138797  https://www.airbnb.com/rooms/49138797  20210412154228
# 4296  49146266  https://www.airbnb.com/rooms/49146266  20210412154228
# 4297  49148812  https://www.airbnb.com/rooms/49148812  20210412154228
# 4298  49153995  https://www.airbnb.com/rooms/49153995  20210412154228
#
#      last_scraped                                               name  \
# 0      2021-04-13                     D1 -  Million Dollar View 2 BR
# 1      2021-04-13  Monthly (or Longer ) Designer One Bedroom Down...
# 2      2021-04-13                       Vancouver's best kept secret
# 3      2021-04-13                                  EcoLoft Vancouver
# 4      2021-04-12        Close to PNE/Hastings Park and East Village
# ...           ...                                                ...
# 4294   2021-04-13   Luxurious 3 Bedroom Unit With English Bay Views!
# 4295   2021-04-13                               19-9-10 Private room
# 4296   2021-04-13             Prime Coal harbour | Luxury Finishings
# 4297   2021-04-13  DT- Ocean View 1BD w/ Private Bathroom Kitchen...
# 4298   2021-04-13                New! High end clean condo downtown!
#
#                                             description  \
# 0     Stunning two bedroom, two bathroom apartment. ...
# 1     <b>The space</b><br />This suites central loca...
# 2     This apartment rents for one month blocks of t...
# 3     The Ecoloft is located in the lovely, family r...
# 4     2 Bedroom garden level guest suite.(lower leve...
# ...                                                 ...
# 4294  Stunning large, modern, brand-new 3 bedroom an...
# 4295  Private room in a new house with shared bathro...
# 4296  Welcome to this beautiful fully furnished Prim...
# 4297  Private one bedroom suite apartment in heart o...
# 4298  Incredible quiet and cozy high floor view suit...
#
#                                   neighborhood_overview  \
# 0                                                   NaN
# 1                                                   NaN
# 2     In the heart of Vancouver, this apartment has ...
# 3     We live in the centre of the city of Vancouver...
# 4     Good Eats, Cute Shops and all the personality ...
# ...                                                 ...
# 4294                                                NaN
# 4295                                                NaN
# 4296  Location, Location, Location! Steps from the S...
# 4297  Heart of Downtown Vancouver , walking distance...
# 4298  Walk score 100%<br />Near everything downtown<...
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/55778229/c2f7...      30899
# 1     https://a0.muscache.com/pictures/c23bb7ef-e300...      52116
# 2     https://a0.muscache.com/pictures/73394727/79d5...      52467
# 3     https://a0.muscache.com/pictures/3646de9b-934e...      56030
# 4     https://a0.muscache.com/pictures/90623667/583c...      63238
# ...                                                 ...        ...
# 4294  https://a0.muscache.com/pictures/d5f23f5b-f10b...  219146817
# 4295  https://a0.muscache.com/pictures/02048308-7b1f...  356993612
# 4296  https://a0.muscache.com/pictures/ee697899-6185...  396405989
# 4297  https://a0.muscache.com/pictures/02a2a9da-68e0...   88405999
# 4298  https://a0.muscache.com/pictures/b0c385f0-c4b5...  188731233
#
#                                          host_url  ...  \
# 0         https://www.airbnb.com/users/show/30899  ...
# 1         https://www.airbnb.com/users/show/52116  ...
# 2         https://www.airbnb.com/users/show/52467  ...
# 3         https://www.airbnb.com/users/show/56030  ...
# 4         https://www.airbnb.com/users/show/63238  ...
# ...                                           ...  ...
# 4294  https://www.airbnb.com/users/show/219146817  ...
# 4295  https://www.airbnb.com/users/show/356993612  ...
# 4296  https://www.airbnb.com/users/show/396405989  ...
# 4297   https://www.airbnb.com/users/show/88405999  ...
# 4298  https://www.airbnb.com/users/show/188731233  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                            9.0                   10.0                 9.0
# 1                           10.0                   10.0                 9.0
# 2                           10.0                   10.0                10.0
# 3                            9.0                   10.0                 9.0
# 4                           10.0                   10.0                 9.0
# ...                          ...                    ...                 ...
# 4294                         NaN                    NaN                 NaN
# 4295                         NaN                    NaN                 NaN
# 4296                         NaN                    NaN                 NaN
# 4297                         NaN                    NaN                 NaN
# 4298                         NaN                    NaN                 NaN
#
#         license instant_bookable calculated_host_listings_count  \
# 0     18-476608                f                             40
# 1     18-611603                f                              1
# 2           NaN                f                              1
# 3     21-156500                t                              1
# 4     19-162421                t                              1
# ...         ...              ...                            ...
# 4294        NaN                f                              5
# 4295  21-107408                f                             14
# 4296        NaN                f                              1
# 4297        NaN                f                              1
# 4298        NaN                f                              2
#
#      calculated_host_listings_count_entire_homes  \
# 0                                             40
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
# ...                                          ...
# 4294                                           5
# 4295                                           1
# 4296                                           1
# 4297                                           1
# 4298                                           2
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 4294                                            0
# 4295                                           13
# 4296                                            0
# 4297                                            0
# 4298                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0              0.14
# 1                                              0              3.27
# 2                                              0              0.73
# 3                                              0              0.26
# 4                                              0              0.15
# ...                                          ...               ...
# 4294                                           0               NaN
# 4295                                           0               NaN
# 4296                                           0               NaN
# 4297                                           0               NaN
# 4298                                           0               NaN
#
# [4299 rows x 74 columns]

# %%
listings_data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
columns_needed = ['host_response_time', 'host_response_rate', 'host_acceptance_rate','host_is_superhost','host_listings_count', 'host_total_listings_count', 'host_identity_verified','neighbourhood_cleansed', 'property_type', 'room_type', 'accommodates', 'bedrooms', 'beds', 'amenities', 'price',   'minimum_nights', 'maximum_nights', 'maximum_nights_avg_ntm',  'availability_30', 'availability_60', 'availability_90','availability_365','number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value', 'reviews_per_month' ]

# %%
listings_data = listings_data[columns_needed]

# %%
listings_data['num_amenities'] = listings_data['amenities'].apply(lambda x: len(x)).astype('float64')
listings_data.drop('amenities', axis= 1, inplace = True)
# Out:
# <ipython-input-7-2c2faca00832>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_data['num_amenities'] = listings_data['amenities'].apply(lambda x: len(x)).astype('float64')
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#Number of Null Values in each column
listings_data.isnull().sum()
# Out:
# host_response_time             1308
# host_response_rate             1308
# host_acceptance_rate           1200
# host_is_superhost               129
# host_listings_count             129
# host_total_listings_count       129
# host_identity_verified          129
# neighbourhood_cleansed            0
# property_type                     0
# room_type                         0
# accommodates                      0
# bedrooms                        312
# beds                             36
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# maximum_nights_avg_ntm            0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews                 0
# review_scores_rating            825
# review_scores_accuracy          837
# review_scores_cleanliness       837
# review_scores_checkin           838
# review_scores_communication     836
# review_scores_location          837
# review_scores_value             837
# reviews_per_month               800
# num_amenities                     0
# dtype: int64

# %%
# remove all rows with any Null Value
listings_data = listings_data.dropna(how='any',axis=0)

# %%
listings_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2109 entries, 0 to 4285
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_response_time           2109 non-null   object
#  1   host_response_rate           2109 non-null   object
#  2   host_acceptance_rate         2109 non-null   object
#  3   host_is_superhost            2109 non-null   object
#  4   host_listings_count          2109 non-null   float64
#  5   host_total_listings_count    2109 non-null   float64
#  6   host_identity_verified       2109 non-null   object
#  7   neighbourhood_cleansed       2109 non-null   object
#  8   property_type                2109 non-null   object
#  9   room_type                    2109 non-null   object
#  10  accommodates                 2109 non-null   int64
#  11  bedrooms                     2109 non-null   float64
#  12  beds                         2109 non-null   float64
#  13  price                        2109 non-null   object
#  14  minimum_nights               2109 non-null   int64
#  15  maximum_nights               2109 non-null   int64
#  16  maximum_nights_avg_ntm       2109 non-null   float64
#  17  availability_30              2109 non-null   int64
#  18  availability_60              2109 non-null   int64
#  19  availability_90              2109 non-null   int64
#  20  availability_365             2109 non-null   int64
#  21  number_of_reviews            2109 non-null   int64
#  22  review_scores_rating         2109 non-null   float64
#  23  review_scores_accuracy       2109 non-null   float64
#  24  review_scores_cleanliness    2109 non-null   float64
#  25  review_scores_checkin        2109 non-null   float64
#  26  review_scores_communication  2109 non-null   float64
#  27  review_scores_location       2109 non-null   float64
#  28  review_scores_value          2109 non-null   float64
#  29  reviews_per_month            2109 non-null   float64
#  30  num_amenities                2109 non-null   float64
# dtypes: float64(14), int64(8), object(9)
# memory usage: 527.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
listings_data['host_response_time'] = lb_make.fit_transform(listings_data['host_response_time'])
listings_data['host_is_superhost'] = lb_make.fit_transform(listings_data['host_is_superhost'])
listings_data['host_identity_verified'] = lb_make.fit_transform(listings_data['host_identity_verified'])
listings_data['neighbourhood_cleansed'] = lb_make.fit_transform(listings_data['neighbourhood_cleansed'])
listings_data['property_type'] = lb_make.fit_transform(listings_data['property_type'])
listings_data['room_type'] = lb_make.fit_transform(listings_data['room_type'])

# %%
listings_data['host_response_rate'].value_counts()
# Out:
# 100%    1597
# 93%       82
# 90%       80
# 80%       33
# 0%        24
# 94%       24
# 99%       22
# 50%       20
# 97%       19
# 92%       16
# 98%       14
# 96%       14
# 95%       13
# 89%       13
# 67%       13
# 70%       12
# 91%       11
# 88%        9
# 75%        9
# 10%        8
# 83%        8
# 71%        8
# 20%        8
# 60%        6
# 17%        5
# 86%        5
# 82%        4
# 81%        3
# 57%        3
# 7%         2
# 85%        2
# 33%        2
# 30%        2
# 84%        2
# 73%        2
# 87%        2
# 18%        2
# 40%        2
# 65%        1
# 25%        1
# 22%        1
# 62%        1
# 77%        1
# 79%        1
# 74%        1
# 72%        1
# Name: host_response_rate, dtype: int64

# %%
#convert % into numbers
listings_data['host_response_rate'] = listings_data['host_response_rate'].apply(lambda x: float(x.replace('%','')))
listings_data['host_acceptance_rate'] = listings_data['host_acceptance_rate'].apply(lambda x: float(x.replace('%','')))
listings_data['price'] = listings_data['price'].apply(lambda x: float(x.replace('$','').replace(',','')))

# %%
# listings_data['host_acceptance_rate'] = listings_data['host_acceptance_rate'].apply(lambda x: (x.replace('%',''))).astype(float64)

# %%
#ML PART

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

# %%
X = listings_data.drop('price',1)

# %%
X
# Out:
#       host_response_time  host_response_rate  host_acceptance_rate  \
# 0                      3                93.0                  87.0
# 1                      1               100.0                  57.0
# 2                      3               100.0                  78.0
# 8                      3               100.0                   0.0
# 9                      3               100.0                 100.0
# ...                  ...                 ...                   ...
# 4242                   3               100.0                 100.0
# 4244                   3               100.0                 100.0
# 4253                   3               100.0                 100.0
# 4260                   3               100.0                 100.0
# 4285                   3               100.0                 100.0
#
#       host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                     0                 49.0                       49.0
# 1                     1                  1.0                        1.0
# 2                     1                  4.0                        4.0
# 8                     0                  2.0                        2.0
# 9                     1                  1.0                        1.0
# ...                 ...                  ...                        ...
# 4242                  0                  2.0                        2.0
# 4244                  0                  1.0                        1.0
# 4253                  0                  0.0                        0.0
# 4260                  0                  2.0                        2.0
# 4285                  0                  1.0                        1.0
#
#       host_identity_verified  neighbourhood_cleansed  property_type  \
# 0                          1                       1              5
# 1                          1                      21              5
# 2                          1                       7              2
# 8                          1                      12             21
# 9                          1                       5             25
# ...                      ...                     ...            ...
# 4242                       1                       9              9
# 4244                       1                       1              2
# 4253                       0                       2              5
# 4260                       1                      12              9
# 4285                       1                      11             27
#
#       room_type  ...  number_of_reviews  review_scores_rating  \
# 0             0  ...                 16                  93.0
# 1             0  ...                430                  93.0
# 2             0  ...                 88                  98.0
# 8             2  ...                118                  91.0
# 9             2  ...                390                 100.0
# ...         ...  ...                ...                   ...
# 4242          0  ...                  2                  80.0
# 4244          0  ...                  1                 100.0
# 4253          0  ...                  2                 100.0
# 4260          0  ...                  1                 100.0
# 4285          2  ...                  2                  90.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                        9.0                        9.0
# 1                        9.0                       10.0
# 2                       10.0                       10.0
# 8                        9.0                        8.0
# 9                       10.0                       10.0
# ...                      ...                        ...
# 4242                     7.0                       10.0
# 4244                    10.0                       10.0
# 4253                    10.0                       10.0
# 4260                    10.0                       10.0
# 4285                    10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# 0                      10.0                          9.0
# 1                       9.0                         10.0
# 2                      10.0                         10.0
# 8                      10.0                         10.0
# 9                      10.0                         10.0
# ...                     ...                          ...
# 4242                    8.0                          8.0
# 4244                   10.0                         10.0
# 4253                   10.0                         10.0
# 4260                   10.0                         10.0
# 4285                   10.0                         10.0
#
#       review_scores_location  review_scores_value  reviews_per_month  \
# 0                       10.0                  9.0               0.14
# 1                       10.0                  9.0               3.27
# 2                       10.0                 10.0               0.73
# 8                       10.0                  9.0               0.96
# 9                       10.0                 10.0               3.25
# ...                      ...                  ...                ...
# 4242                    10.0                 10.0               2.00
# 4244                    10.0                 10.0               1.00
# 4253                    10.0                 10.0               2.00
# 4260                    10.0                 10.0               1.00
# 4285                    10.0                 10.0               2.00
#
#       num_amenities
# 0             462.0
# 1             520.0
# 2             914.0
# 8             308.0
# 9             611.0
# ...             ...
# 4242          750.0
# 4244          581.0
# 4253          658.0
# 4260          863.0
# 4285          189.0
#
# [2109 rows x 30 columns]

# %%
y = listings_data['price']

# %%
y
# Out:
# 0       150.0
# 1        85.0
# 2       145.0
# 8        51.0
# 9        79.0
#         ...
# 4242     58.0
# 4244    140.0
# 4253    117.0
# 4260     85.0
# 4285     75.0
# Name: price, Length: 2109, dtype: float64

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y)

# %%
model = KNeighborsRegressor(50)
model.fit(X_train, y_train)
print(model.score(X_valid, y_valid))
# Out:
# 0.07034827006506006

# %%
model = RandomForestRegressor(100, max_depth=40)
model.fit(X_train, y_train)
print(model.score(X_valid, y_valid))
# Out:
# 0.4746936561645575

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor()
model.fit(X_train, y_train)
print(model.score(X_valid, y_valid))
# Out:
# 0.45881656988728825
