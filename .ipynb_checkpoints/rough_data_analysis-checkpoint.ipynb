# %%
import pandas as pd
import numpy as np

# %%
listings_data = pd.read_csv('listings.csv.gz')

# %%
listings_data
# Out:
#             id                            listing_url       scrape_id  \
# 0        10080     https://www.airbnb.com/rooms/10080  20210412154228
# 1        13358     https://www.airbnb.com/rooms/13358  20210412154228
# 2        13490     https://www.airbnb.com/rooms/13490  20210412154228
# 3        14267     https://www.airbnb.com/rooms/14267  20210412154228
# 4        16254     https://www.airbnb.com/rooms/16254  20210412154228
# ...        ...                                    ...             ...
# 4294  49132295  https://www.airbnb.com/rooms/49132295  20210412154228
# 4295  49138797  https://www.airbnb.com/rooms/49138797  20210412154228
# 4296  49146266  https://www.airbnb.com/rooms/49146266  20210412154228
# 4297  49148812  https://www.airbnb.com/rooms/49148812  20210412154228
# 4298  49153995  https://www.airbnb.com/rooms/49153995  20210412154228
#
#      last_scraped                                               name  \
# 0      2021-04-13                     D1 -  Million Dollar View 2 BR
# 1      2021-04-13  Monthly (or Longer ) Designer One Bedroom Down...
# 2      2021-04-13                       Vancouver's best kept secret
# 3      2021-04-13                                  EcoLoft Vancouver
# 4      2021-04-12        Close to PNE/Hastings Park and East Village
# ...           ...                                                ...
# 4294   2021-04-13   Luxurious 3 Bedroom Unit With English Bay Views!
# 4295   2021-04-13                               19-9-10 Private room
# 4296   2021-04-13             Prime Coal harbour | Luxury Finishings
# 4297   2021-04-13  DT- Ocean View 1BD w/ Private Bathroom Kitchen...
# 4298   2021-04-13                New! High end clean condo downtown!
#
#                                             description  \
# 0     Stunning two bedroom, two bathroom apartment. ...
# 1     <b>The space</b><br />This suites central loca...
# 2     This apartment rents for one month blocks of t...
# 3     The Ecoloft is located in the lovely, family r...
# 4     2 Bedroom garden level guest suite.(lower leve...
# ...                                                 ...
# 4294  Stunning large, modern, brand-new 3 bedroom an...
# 4295  Private room in a new house with shared bathro...
# 4296  Welcome to this beautiful fully furnished Prim...
# 4297  Private one bedroom suite apartment in heart o...
# 4298  Incredible quiet and cozy high floor view suit...
#
#                                   neighborhood_overview  \
# 0                                                   NaN
# 1                                                   NaN
# 2     In the heart of Vancouver, this apartment has ...
# 3     We live in the centre of the city of Vancouver...
# 4     Good Eats, Cute Shops and all the personality ...
# ...                                                 ...
# 4294                                                NaN
# 4295                                                NaN
# 4296  Location, Location, Location! Steps from the S...
# 4297  Heart of Downtown Vancouver , walking distance...
# 4298  Walk score 100%<br />Near everything downtown<...
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/55778229/c2f7...      30899
# 1     https://a0.muscache.com/pictures/c23bb7ef-e300...      52116
# 2     https://a0.muscache.com/pictures/73394727/79d5...      52467
# 3     https://a0.muscache.com/pictures/3646de9b-934e...      56030
# 4     https://a0.muscache.com/pictures/90623667/583c...      63238
# ...                                                 ...        ...
# 4294  https://a0.muscache.com/pictures/d5f23f5b-f10b...  219146817
# 4295  https://a0.muscache.com/pictures/02048308-7b1f...  356993612
# 4296  https://a0.muscache.com/pictures/ee697899-6185...  396405989
# 4297  https://a0.muscache.com/pictures/02a2a9da-68e0...   88405999
# 4298  https://a0.muscache.com/pictures/b0c385f0-c4b5...  188731233
#
#                                          host_url  ...  \
# 0         https://www.airbnb.com/users/show/30899  ...
# 1         https://www.airbnb.com/users/show/52116  ...
# 2         https://www.airbnb.com/users/show/52467  ...
# 3         https://www.airbnb.com/users/show/56030  ...
# 4         https://www.airbnb.com/users/show/63238  ...
# ...                                           ...  ...
# 4294  https://www.airbnb.com/users/show/219146817  ...
# 4295  https://www.airbnb.com/users/show/356993612  ...
# 4296  https://www.airbnb.com/users/show/396405989  ...
# 4297   https://www.airbnb.com/users/show/88405999  ...
# 4298  https://www.airbnb.com/users/show/188731233  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                            9.0                   10.0                 9.0
# 1                           10.0                   10.0                 9.0
# 2                           10.0                   10.0                10.0
# 3                            9.0                   10.0                 9.0
# 4                           10.0                   10.0                 9.0
# ...                          ...                    ...                 ...
# 4294                         NaN                    NaN                 NaN
# 4295                         NaN                    NaN                 NaN
# 4296                         NaN                    NaN                 NaN
# 4297                         NaN                    NaN                 NaN
# 4298                         NaN                    NaN                 NaN
#
#         license instant_bookable calculated_host_listings_count  \
# 0     18-476608                f                             40
# 1     18-611603                f                              1
# 2           NaN                f                              1
# 3     21-156500                t                              1
# 4     19-162421                t                              1
# ...         ...              ...                            ...
# 4294        NaN                f                              5
# 4295  21-107408                f                             14
# 4296        NaN                f                              1
# 4297        NaN                f                              1
# 4298        NaN                f                              2
#
#      calculated_host_listings_count_entire_homes  \
# 0                                             40
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
# ...                                          ...
# 4294                                           5
# 4295                                           1
# 4296                                           1
# 4297                                           1
# 4298                                           2
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 4294                                            0
# 4295                                           13
# 4296                                            0
# 4297                                            0
# 4298                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0              0.14
# 1                                              0              3.27
# 2                                              0              0.73
# 3                                              0              0.26
# 4                                              0              0.15
# ...                                          ...               ...
# 4294                                           0               NaN
# 4295                                           0               NaN
# 4296                                           0               NaN
# 4297                                           0               NaN
# 4298                                           0               NaN
#
# [4299 rows x 74 columns]

# %%
listings_data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
col = ['last_review', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value']

# %%
lis = listings_data[col]

# %%
lis
# Out:
#      last_review  review_scores_rating  review_scores_accuracy  \
# 0     2017-02-26                  93.0                     9.0
# 1     2021-01-01                  93.0                     9.0
# 2     2020-10-31                  98.0                    10.0
# 3     2020-02-07                  95.0                    10.0
# 4     2019-08-19                  96.0                    10.0
# ...          ...                   ...                     ...
# 4294         NaN                   NaN                     NaN
# 4295         NaN                   NaN                     NaN
# 4296         NaN                   NaN                     NaN
# 4297         NaN                   NaN                     NaN
# 4298         NaN                   NaN                     NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                           9.0                   10.0
# 1                          10.0                    9.0
# 2                          10.0                   10.0
# 3                           9.0                   10.0
# 4                          10.0                   10.0
# ...                         ...                    ...
# 4294                        NaN                    NaN
# 4295                        NaN                    NaN
# 4296                        NaN                    NaN
# 4297                        NaN                    NaN
# 4298                        NaN                    NaN
#
#       review_scores_communication  review_scores_location  review_scores_value
# 0                             9.0                    10.0                  9.0
# 1                            10.0                    10.0                  9.0
# 2                            10.0                    10.0                 10.0
# 3                             9.0                    10.0                  9.0
# 4                            10.0                    10.0                  9.0
# ...                           ...                     ...                  ...
# 4294                          NaN                     NaN                  NaN
# 4295                          NaN                     NaN                  NaN
# 4296                          NaN                     NaN                  NaN
# 4297                          NaN                     NaN                  NaN
# 4298                          NaN                     NaN                  NaN
#
# [4299 rows x 8 columns]

# %%
lis["review_scores_rating"].isna().sum()
# Out:
# 825

# %%
columns_needed = ['id', 'listing_url', 'name', 'description', 'picture_url', 'latitude', 'longitude', 'property_type', 'accommodates', 'bedrooms', 'beds', 'amenities', 'price' ]

# %%
listings_data = listings_data[columns_needed]

# %%
listings_data
# Out:
#             id                            listing_url  \
# 0        10080     https://www.airbnb.com/rooms/10080
# 1        13358     https://www.airbnb.com/rooms/13358
# 2        13490     https://www.airbnb.com/rooms/13490
# 3        14267     https://www.airbnb.com/rooms/14267
# 4        16254     https://www.airbnb.com/rooms/16254
# ...        ...                                    ...
# 4294  49132295  https://www.airbnb.com/rooms/49132295
# 4295  49138797  https://www.airbnb.com/rooms/49138797
# 4296  49146266  https://www.airbnb.com/rooms/49146266
# 4297  49148812  https://www.airbnb.com/rooms/49148812
# 4298  49153995  https://www.airbnb.com/rooms/49153995
#
#                                                    name  \
# 0                        D1 -  Million Dollar View 2 BR
# 1     Monthly (or Longer ) Designer One Bedroom Down...
# 2                          Vancouver's best kept secret
# 3                                     EcoLoft Vancouver
# 4           Close to PNE/Hastings Park and East Village
# ...                                                 ...
# 4294   Luxurious 3 Bedroom Unit With English Bay Views!
# 4295                               19-9-10 Private room
# 4296             Prime Coal harbour | Luxury Finishings
# 4297  DT- Ocean View 1BD w/ Private Bathroom Kitchen...
# 4298                New! High end clean condo downtown!
#
#                                             description  \
# 0     Stunning two bedroom, two bathroom apartment. ...
# 1     <b>The space</b><br />This suites central loca...
# 2     This apartment rents for one month blocks of t...
# 3     The Ecoloft is located in the lovely, family r...
# 4     2 Bedroom garden level guest suite.(lower leve...
# ...                                                 ...
# 4294  Stunning large, modern, brand-new 3 bedroom an...
# 4295  Private room in a new house with shared bathro...
# 4296  Welcome to this beautiful fully furnished Prim...
# 4297  Private one bedroom suite apartment in heart o...
# 4298  Incredible quiet and cozy high floor view suit...
#
#                                             picture_url  latitude  longitude  \
# 0     https://a0.muscache.com/pictures/55778229/c2f7...  49.28872 -123.12046
# 1     https://a0.muscache.com/pictures/c23bb7ef-e300...  49.28201 -123.12669
# 2     https://a0.muscache.com/pictures/73394727/79d5...  49.25622 -123.06607
# 3     https://a0.muscache.com/pictures/3646de9b-934e...  49.24922 -123.08139
# 4     https://a0.muscache.com/pictures/90623667/583c...  49.27721 -123.04086
# ...                                                 ...       ...        ...
# 4294  https://a0.muscache.com/pictures/d5f23f5b-f10b...  49.27391 -123.13012
# 4295  https://a0.muscache.com/pictures/02048308-7b1f...  49.25275 -123.09184
# 4296  https://a0.muscache.com/pictures/ee697899-6185...  49.28631 -123.12455
# 4297  https://a0.muscache.com/pictures/02a2a9da-68e0...  49.28822 -123.13061
# 4298  https://a0.muscache.com/pictures/b0c385f0-c4b5...  49.27849 -123.12562
#
#               property_type  accommodates  bedrooms  beds  \
# 0        Entire condominium             5       2.0   2.0
# 1        Entire condominium             2       1.0   1.0
# 2          Entire apartment             2       1.0   1.0
# 3              Entire house             4       1.0   2.0
# 4        Entire guest suite             4       2.0   3.0
# ...                     ...           ...       ...   ...
# 4294       Entire apartment             7       3.0   5.0
# 4295  Private room in house             2       1.0   1.0
# 4296       Entire apartment             2       1.0   NaN
# 4297       Entire apartment             1       1.0   1.0
# 4298     Entire condominium             2       NaN   0.0
#
#                                               amenities    price
# 0     ["Iron", "Dryer", "Bed linens", "Cooking basic...  $150.00
# 1     ["Iron", "Dryer", "Bed linens", "Cooking basic...   $85.00
# 2     ["Iron", "Outdoor dining area", "Ethernet conn...  $145.00
# 3     ["Iron", "Dryer", "Cooking basics", "Hot water...  $140.00
# 4     ["Iron", "Dryer", "Bed linens", "Cooking basic...  $195.00
# ...                                                 ...      ...
# 4294  ["Heating", "Essentials", "Kitchen", "Iron", "...  $500.00
# 4295  ["Heating", "Kitchen", "Fire extinguisher", "D...   $38.00
# 4296  ["Kitchen", "Body soap", "Shampoo", "Hot tub",...  $160.00
# 4297  ["Dryer", "Bed linens", "Elevator", "Paid park...   $66.00
# 4298  ["Ethernet connection", "Hot tub", "Dryer", "B...   $73.00
#
# [4299 rows x 13 columns]

# %%
def clean_amenities_data(amenities_data):

    #find unique amenities and the number of them to choose which are important for a traveller
    print(amenities_data['amenity'].value_counts())

    # choose important amenities to work with
    amenities_required = ['restaurent', 'fast_food', 'cafe','bank','atm','pharmacy','bicycle_rental','fuel','pub','bar','car_sharing','car_rental','clinic','doctors','hospital','ice_cream','fountain','theatre','police','bus_station']
    #adapted from : https://www.kite.com/python/answers/how-to-filter-a-pandas-dataframe-with-a-list-by-%60in%60-or-%60not-in%60-in-python
    bool_series = amenities_data.amenity.isin(amenities_required)
    filtered_amenities_df = amenities_data[bool_series]
    filtered_amenities_df.reset_index(inplace=True, drop=True)

    return filtered_amenities_df

# %%
amenities_data = pd.read_json('amenities-vancouver.json.gz', lines=True)
amenities_data_clean = clean_amenities_data(amenities_data)
# Out:
# bench              3738
# restaurant         2472
# bicycle_parking    1423
# fast_food          1147
# waste_basket       1137
#                    ...
# park                  1
# first_aid             1
# biergarten            1
# gym                   1
# casino                1
# Name: amenity, Length: 138, dtype: int64

# %%
amenities_data_clean
# Out:
#             lat         lon                      timestamp    amenity  \
# 0     49.260812 -123.125736  2020-03-20T18:22:12.000-07:00       cafe
# 1     49.260953 -123.125704  2019-08-02T18:11:20.000-07:00  fast_food
# 2     49.264041 -123.153407  2019-08-29T18:50:05.000-07:00       fuel
# 3     49.283192 -123.109050  2015-12-18T21:41:07.000-08:00        pub
# 4     49.082281 -122.056130  2018-02-12T01:42:34.000-08:00       fuel
# ...         ...         ...                            ...        ...
# 4456  49.264044 -123.174166  2019-09-13T13:56:49.000-07:00       cafe
# 4457  49.263998 -123.173758  2019-06-08T06:31:22.000-07:00  fast_food
# 4458  49.278424 -122.806704  2013-03-26T23:45:49.000-07:00       cafe
# 4459  49.282666 -122.826978  2019-09-13T13:56:49.000-07:00        pub
# 4460  49.282420 -122.826340  2019-09-13T13:56:49.000-07:00       cafe
#
#                       name                                               tags
# 0                Starbucks  {'brand:wikidata': 'Q37158', 'official_name': ...
# 1               Salad Loop  {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...
# 2                    Shell  {'brand:wikidata': 'Q154950', 'addr:housenumbe...
# 3               The Cambie  {'toilets:wheelchair': 'no', 'wheelchair': 'li...
# 4             Petro-Canada                       {'name:en': 'Petrol Canada'}
# ...                    ...                                                ...
# 4456           Tim Hortons  {'brand:wikidata': 'Q175106', 'addr:housenumbe...
# 4457                Subway  {'brand:wikidata': 'Q244457', 'website': 'http...
# 4458      Creekside Coffee                                                 {}
# 4459  Brown's Social House  {'addr:housenumber': '215', 'brewery': 'Guinne...
# 4460      Gallagher's Cafe  {'addr:housenumber': '232', 'internet_access':...
#
# [4461 rows x 6 columns]

# %%
ad= amenities_data_clean.head(5)
ad
# Out:
#          lat         lon                      timestamp    amenity  \
# 0  49.260812 -123.125736  2020-03-20T18:22:12.000-07:00       cafe
# 1  49.260953 -123.125704  2019-08-02T18:11:20.000-07:00  fast_food
# 2  49.264041 -123.153407  2019-08-29T18:50:05.000-07:00       fuel
# 3  49.283192 -123.109050  2015-12-18T21:41:07.000-08:00        pub
# 4  49.082281 -122.056130  2018-02-12T01:42:34.000-08:00       fuel
#
#            name                                               tags
# 0     Starbucks  {'brand:wikidata': 'Q37158', 'official_name': ...
# 1    Salad Loop  {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...
# 2         Shell  {'brand:wikidata': 'Q154950', 'addr:housenumbe...
# 3    The Cambie  {'toilets:wheelchair': 'no', 'wheelchair': 'li...
# 4  Petro-Canada                       {'name:en': 'Petrol Canada'}

# %%
ad[['name']] = ad[['name']].apply(lambda x: 1 if x == 'Shell' else 0)
ad
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e01f7f729816> in <module>
# ----> 1 ad[['name']] = ad[['name']].apply(lambda x: 1 if x == 'Shell' else 0)
#       2 ad
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-36-e01f7f729816> in <lambda>(x)
# ----> 1 ad[['name']] = ad[['name']].apply(lambda x: 1 if x == 'Shell' else 0)
#       2 ad
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
amenities_data_clean['amenity'].unique()
# Out:
# array(['cafe', 'fast_food', 'fuel', 'pub', 'pharmacy', 'doctors', 'atm',
#        'bank', 'theatre', 'bar', 'car_rental', 'car_sharing',
#        'bicycle_rental', 'clinic', 'ice_cream', 'fountain', 'bus_station',
#        'hospital', 'police'], dtype=object)

# %%
amenities_required = ['restaurent', 'fast_food', 'cafe','bank','atm','pharmacy','fuel','car_rental','clinic','doctors','hospital','ice_cream','fountain','theatre']

# %%
amenities_required
# Out:
# ['restaurent',
#  'fast_food',
#  'cafe',
#  'bank',
#  'atm',
#  'pharmacy',
#  'fuel',
#  'car_rental',
#  'clinic',
#  'doctors',
#  'hospital',
#  'ice_cream',
#  'fountain',
#  'theatre']

# %%
d = dict.fromkeys(amenities_required, 0)

# %%
d
# Out:
# {'restaurent': 0,
#  'fast_food': 0,
#  'cafe': 0,
#  'bank': 0,
#  'atm': 0,
#  'pharmacy': 0,
#  'fuel': 0,
#  'car_rental': 0,
#  'clinic': 0,
#  'doctors': 0,
#  'hospital': 0,
#  'ice_cream': 0,
#  'fountain': 0,
#  'theatre': 0}

# %%
d['fuel'] +=1

# %%
d
# Out:
# {'restaurent': 0,
#  'fast_food': 0,
#  'cafe': 0,
#  'bank': 0,
#  'atm': 0,
#  'pharmacy': 0,
#  'fuel': 3,
#  'car_rental': 0,
#  'clinic': 0,
#  'doctors': 0,
#  'hospital': 0,
#  'ice_cream': 0,
#  'fountain': 0,
#  'theatre': 0}

# %%
def haversine_distance(lon1, lat1, lon2, lat2):
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r * 1000

# %%
# return a dictionary with number of amenities in a 1km radius of this lat and lon
def num_amenities(lat, lon, amenities_data_clean, amenities_required):
    amenities_dict = dict.fromkeys(amenities_required,0)
    
    
    
    #amenities_data_clean.apply(lambda x:amenities_dict[x['amenity']]=1 if (haversine_distance(lon, lat, x['lon'], x['lat']) <=1000))
    
    
    
    print(amenities_dict)
# Out:
#   File "<ipython-input-32-f97d67faf92b>", line 5
#     amenities_data_clean.apply(lambda x:amenities_dict[x['amenity']]=1 if (haversine_distance(lon, lat, x['lon'], x['lat']) <=1000))
#                                                                                                                                    ^
# SyntaxError: invalid syntax
