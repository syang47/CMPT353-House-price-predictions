# %%
import pandas as pd
import numpy as np
from math import radians, cos, sin, asin, sqrt

def read_data():
    listings_data = pd.read_csv('listings.csv.gz')
    amenities_data = pd.read_json('amenities-vancouver.json.gz', lines=True)
    return listings_data, amenities_data


def clean_amenities_data(amenities_data, amenities_required):

    #find unique amenities and the number of them to choose which are important for a traveller
    # print(amenities_data['amenity'].value_counts())

    #adapted from : https://www.kite.com/python/answers/how-to-filter-a-pandas-dataframe-with-a-list-by-%60in%60-or-%60not-in%60-in-python
    bool_series = amenities_data.amenity.isin(amenities_required)
    filtered_amenities_df = amenities_data[bool_series]
    filtered_amenities_df = filtered_amenities_df.drop(['timestamp','tags'], axis=1).dropna() # dropping unnecessary columns, and filter out NA values
    filtered_amenities_df.reset_index(inplace=True, drop=True)

    return filtered_amenities_df


#reference: https://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points
def haversine_distance(lon1, lat1, lon2, lat2):
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r * 1000

def haversine_distance2(df, lon2, lat2):
    # convert decimal degrees to radians 
    lon1=np.radians(df['lon'])
    lat1=np.radians(df['lat'])
    lon2=np.radians(lon2)
    lat2=np.radians(lat2)
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = (dlat/2).apply(sin)**2 + (lat1).apply(sin) * cos(lat2) * (dlon/2).apply(sin)**2
    c = 2 * ((a).apply(sqrt).apply(asin)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r * 1000

def clean_listings_data(listings_data):
    #keep only the columns we need
    columns_needed = ['id', 'listing_url', 'name', 'description', 'picture_url', 'latitude', 'longitude', 'property_type', 'accommodates', 'bedrooms', 'beds', 'amenities', 'price']
    listings_data = listings_data[columns_needed]
    return listings_data


# #TODO: return a dictionary with number of amenities in a 1km radius of this lat and lon
def num_amenities(lat, lon, amenities_data_clean):
    distance = haversine_distance2(amenities_data_clean, lon, lat)
    amenities_data_clean['distance'] = distance
    data_withinR = amenities_data_clean.loc[amenities_data_clean['distance'] < 1000].reset_index(drop=True)
    amenities_series = data_withinR.pivot_table(columns = ['amenity'], aggfunc='size')  # Counts # of amenities, type=pd.series
    amenities_dict = amenities_series.to_dict()# converts series to dict
    return amenities_dict

# %%
#Read Data
listings_data, amenities_data = read_data()

# Change amenities here (updated the "restaurant" typo)
amenities_required = ['restaurant', 'fast_food', 'cafe','bank','atm','pharmacy','bicycle_rental','fuel','pub','bar','car_sharing','car_rental','clinic','doctors','hospital','ice_cream','fountain','theatre','police','bus_station']

#Data Cleaning
amenities_data_clean = clean_amenities_data(amenities_data, amenities_required)
listings_data_clean = clean_listings_data(listings_data)


#Return a dict of amenities:
lat_input = 49.225164  # sample lat input
lon_input = -123.003742  # sample lon input
amen_dict = num_amenities(lat_input, lon_input, amenities_data_clean)

# %%
amen_dict
# Out:
# {'bank': 16,
#  'bar': 16,
#  'bus_station': 1,
#  'cafe': 27,
#  'car_rental': 1,
#  'clinic': 8,
#  'fast_food': 61,
#  'fountain': 1,
#  'fuel': 1,
#  'ice_cream': 1,
#  'pharmacy': 9,
#  'police': 1,
#  'pub': 1,
#  'restaurant': 56}

# %%
listings_data_clean['accommodates'].max()
# Out:
# 16

# %%
listings_data_clean.loc[listings_data_clean['accommodates'] == 17]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, name, description, picture_url, latitude, longitude, property_type, accommodates, bedrooms, beds, amenities, price]
# Index: []

# %%
listings_data_clean.empty
# Out:
# False

# %%
listings_data_clean = listings_data_clean.head(100)
listings_data_clean
# Out:
#         id                          listing_url  \
# 0    10080   https://www.airbnb.com/rooms/10080
# 1    13358   https://www.airbnb.com/rooms/13358
# 2    13490   https://www.airbnb.com/rooms/13490
# 3    14267   https://www.airbnb.com/rooms/14267
# 4    16254   https://www.airbnb.com/rooms/16254
# ..     ...                                  ...
# 95  944021  https://www.airbnb.com/rooms/944021
# 96  958090  https://www.airbnb.com/rooms/958090
# 97  961006  https://www.airbnb.com/rooms/961006
# 98  961831  https://www.airbnb.com/rooms/961831
# 99  980511  https://www.airbnb.com/rooms/980511
#
#                                                  name  \
# 0                      D1 -  Million Dollar View 2 BR
# 1   Monthly (or Longer ) Designer One Bedroom Down...
# 2                        Vancouver's best kept secret
# 3                                   EcoLoft Vancouver
# 4         Close to PNE/Hastings Park and East Village
# ..                                                ...
# 95       Modern Serenity - Heart of Yaletown/Downtown
# 96                Private apartment-Yaletown Downtown
# 97     Oakridge Canada Line completely renovated home
# 98                    Spacious Room in Character Home
# 99                     261 Yaletown Studio at "Space"
#
#                                           description  \
# 0   Stunning two bedroom, two bathroom apartment. ...
# 1   <b>The space</b><br />This suites central loca...
# 2   This apartment rents for one month blocks of t...
# 3   The Ecoloft is located in the lovely, family r...
# 4   2 Bedroom garden level guest suite.(lower leve...
# ..                                                ...
# 95  Whether you're in town for business, or lookin...
# 96  <b>The space</b><br />I have been an airbnb ho...
# 97  Bright 2 BR garden suite in a Newly renovated ...
# 98  Large bedroom in a very spacious heritage hous...
# 99  "Space"- the building! Studio on the 30th floo...
#
#                                           picture_url  latitude  longitude  \
# 0   https://a0.muscache.com/pictures/55778229/c2f7...  49.28872 -123.12046
# 1   https://a0.muscache.com/pictures/c23bb7ef-e300...  49.28201 -123.12669
# 2   https://a0.muscache.com/pictures/73394727/79d5...  49.25622 -123.06607
# 3   https://a0.muscache.com/pictures/3646de9b-934e...  49.24922 -123.08139
# 4   https://a0.muscache.com/pictures/90623667/583c...  49.27721 -123.04086
# ..                                                ...       ...        ...
# 95  https://a0.muscache.com/pictures/miso/Hosting-...  49.27805 -123.11794
# 96  https://a0.muscache.com/pictures/14252294/5842...  49.27744 -123.11524
# 97  https://a0.muscache.com/pictures/d4f28caa-bb4d...  49.23569 -123.10987
# 98  https://a0.muscache.com/pictures/miso/Hosting-...  49.26648 -123.15939
# 99  https://a0.muscache.com/pictures/fe1df622-0f9b...  49.27489 -123.12654
#
#             property_type  accommodates  bedrooms  beds  \
# 0      Entire condominium             5       2.0   2.0
# 1      Entire condominium             2       1.0   1.0
# 2        Entire apartment             2       1.0   1.0
# 3            Entire house             4       1.0   2.0
# 4      Entire guest suite             4       2.0   3.0
# ..                    ...           ...       ...   ...
# 95     Entire condominium             2       1.0   1.0
# 96       Entire apartment             4       NaN   2.0
# 97     Entire guest suite             4       2.0   2.0
# 98  Private room in house             2       1.0   1.0
# 99       Entire apartment             2       NaN   1.0
#
#                                             amenities    price
# 0   ["Iron", "Dryer", "Bed linens", "Cooking basic...  $150.00
# 1   ["Iron", "Dryer", "Bed linens", "Cooking basic...   $85.00
# 2   ["Iron", "Outdoor dining area", "Ethernet conn...  $145.00
# 3   ["Iron", "Dryer", "Cooking basics", "Hot water...  $140.00
# 4   ["Iron", "Dryer", "Bed linens", "Cooking basic...  $195.00
# ..                                                ...      ...
# 95  ["Iron", "Dryer", "Bed linens", "Cooking basic...  $130.00
# 96  ["Heating", "Kitchen", "Gym", "Hot tub", "Drye...  $499.00
# 97  ["Iron", "Dryer", "Hot water", "Essentials", "...  $219.00
# 98  ["Kitchen", "Essentials", "Iron", "Fire exting...   $55.00
# 99  ["Iron", "Dryer", "Elevator", "Cooking basics"...   $70.00
#
# [100 rows x 13 columns]

# %%
listings_data_clean['num_amenities_nearby'] = listings_data_clean.apply(lambda x: num_amenities(x['latitude'], x['longitude'], amenities_data_clean), axis = 1)

# %%
listings_data_clean
# Out:
#         id                          listing_url  \
# 0    10080   https://www.airbnb.com/rooms/10080
# 1    13358   https://www.airbnb.com/rooms/13358
# 2    13490   https://www.airbnb.com/rooms/13490
# 3    14267   https://www.airbnb.com/rooms/14267
# 4    16254   https://www.airbnb.com/rooms/16254
# ..     ...                                  ...
# 95  944021  https://www.airbnb.com/rooms/944021
# 96  958090  https://www.airbnb.com/rooms/958090
# 97  961006  https://www.airbnb.com/rooms/961006
# 98  961831  https://www.airbnb.com/rooms/961831
# 99  980511  https://www.airbnb.com/rooms/980511
#
#                                                  name  \
# 0                      D1 -  Million Dollar View 2 BR
# 1   Monthly (or Longer ) Designer One Bedroom Down...
# 2                        Vancouver's best kept secret
# 3                                   EcoLoft Vancouver
# 4         Close to PNE/Hastings Park and East Village
# ..                                                ...
# 95       Modern Serenity - Heart of Yaletown/Downtown
# 96                Private apartment-Yaletown Downtown
# 97     Oakridge Canada Line completely renovated home
# 98                    Spacious Room in Character Home
# 99                     261 Yaletown Studio at "Space"
#
#                                           description  \
# 0   Stunning two bedroom, two bathroom apartment. ...
# 1   <b>The space</b><br />This suites central loca...
# 2   This apartment rents for one month blocks of t...
# 3   The Ecoloft is located in the lovely, family r...
# 4   2 Bedroom garden level guest suite.(lower leve...
# ..                                                ...
# 95  Whether you're in town for business, or lookin...
# 96  <b>The space</b><br />I have been an airbnb ho...
# 97  Bright 2 BR garden suite in a Newly renovated ...
# 98  Large bedroom in a very spacious heritage hous...
# 99  "Space"- the building! Studio on the 30th floo...
#
#                                           picture_url  latitude  longitude  \
# 0   https://a0.muscache.com/pictures/55778229/c2f7...  49.28872 -123.12046
# 1   https://a0.muscache.com/pictures/c23bb7ef-e300...  49.28201 -123.12669
# 2   https://a0.muscache.com/pictures/73394727/79d5...  49.25622 -123.06607
# 3   https://a0.muscache.com/pictures/3646de9b-934e...  49.24922 -123.08139
# 4   https://a0.muscache.com/pictures/90623667/583c...  49.27721 -123.04086
# ..                                                ...       ...        ...
# 95  https://a0.muscache.com/pictures/miso/Hosting-...  49.27805 -123.11794
# 96  https://a0.muscache.com/pictures/14252294/5842...  49.27744 -123.11524
# 97  https://a0.muscache.com/pictures/d4f28caa-bb4d...  49.23569 -123.10987
# 98  https://a0.muscache.com/pictures/miso/Hosting-...  49.26648 -123.15939
# 99  https://a0.muscache.com/pictures/fe1df622-0f9b...  49.27489 -123.12654
#
#             property_type  accommodates  bedrooms  beds  \
# 0      Entire condominium             5       2.0   2.0
# 1      Entire condominium             2       1.0   1.0
# 2        Entire apartment             2       1.0   1.0
# 3            Entire house             4       1.0   2.0
# 4      Entire guest suite             4       2.0   3.0
# ..                    ...           ...       ...   ...
# 95     Entire condominium             2       1.0   1.0
# 96       Entire apartment             4       NaN   2.0
# 97     Entire guest suite             4       2.0   2.0
# 98  Private room in house             2       1.0   1.0
# 99       Entire apartment             2       NaN   1.0
#
#                                             amenities    price  \
# 0   ["Iron", "Dryer", "Bed linens", "Cooking basic...  $150.00
# 1   ["Iron", "Dryer", "Bed linens", "Cooking basic...   $85.00
# 2   ["Iron", "Outdoor dining area", "Ethernet conn...  $145.00
# 3   ["Iron", "Dryer", "Cooking basics", "Hot water...  $140.00
# 4   ["Iron", "Dryer", "Bed linens", "Cooking basic...  $195.00
# ..                                                ...      ...
# 95  ["Iron", "Dryer", "Bed linens", "Cooking basic...  $130.00
# 96  ["Heating", "Kitchen", "Gym", "Hot tub", "Drye...  $499.00
# 97  ["Iron", "Dryer", "Hot water", "Essentials", "...  $219.00
# 98  ["Kitchen", "Essentials", "Iron", "Fire exting...   $55.00
# 99  ["Iron", "Dryer", "Elevator", "Cooking basics"...   $70.00
#
#                                  num_amenities_nearby
# 0   {'atm': 1, 'bank': 21, 'bar': 9, 'bicycle_rent...
# 1   {'atm': 1, 'bank': 30, 'bar': 27, 'bicycle_ren...
# 2   {'bank': 4, 'bicycle_rental': 7, 'cafe': 7, 'c...
# 3   {'bank': 3, 'bicycle_rental': 2, 'cafe': 7, 'c...
# 4   {'bank': 4, 'cafe': 6, 'doctors': 4, 'fast_foo...
# ..                                                ...
# 95  {'atm': 1, 'bank': 29, 'bar': 28, 'bicycle_ren...
# 96  {'atm': 1, 'bank': 23, 'bar': 28, 'bicycle_ren...
# 97  {'bank': 7, 'cafe': 5, 'fast_food': 1, 'fuel':...
# 98  {'bank': 8, 'bicycle_rental': 9, 'cafe': 28, '...
# 99  {'atm': 1, 'bank': 11, 'bar': 22, 'bicycle_ren...
#
# [100 rows x 14 columns]

# %%
listings_data_clean['price'] = listings_data_clean['price'].apply(lambda x: float(x.replace('$','').replace(',','')))

# %%
listings_data_clean = listings_data_clean.loc[(listings_data_clean['price'] <= 150) & (listings_data_clean['accommodates'] >= 3) & (listings_data_clean['bedrooms'] >= 2)]

# %%
listings_data_clean.reset_index(drop = True, inplace = True)

# %%
listings_data_clean['len_dict'] = listings_data_clean['num_amenities_nearby'].apply(lambda x : len(x))
# Out:
# <ipython-input-38-c9ec4e26f2ca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_data_clean['len_dict'] = listings_data_clean['num_amenities_nearby'].apply(lambda x : len(x))

# %%
listings_data_clean
# Out:
#         id                          listing_url  \
# 0    10080   https://www.airbnb.com/rooms/10080
# 1    16611   https://www.airbnb.com/rooms/16611
# 2    17158   https://www.airbnb.com/rooms/17158
# 3    20085   https://www.airbnb.com/rooms/20085
# 4    35102   https://www.airbnb.com/rooms/35102
# 5   111077  https://www.airbnb.com/rooms/111077
# 6   170137  https://www.airbnb.com/rooms/170137
# 7   219261  https://www.airbnb.com/rooms/219261
# 8   248014  https://www.airbnb.com/rooms/248014
# 9   311354  https://www.airbnb.com/rooms/311354
# 10  523272  https://www.airbnb.com/rooms/523272
# 11  654744  https://www.airbnb.com/rooms/654744
# 12  755558  https://www.airbnb.com/rooms/755558
# 13  785752  https://www.airbnb.com/rooms/785752
#
#                                                  name  \
# 0                      D1 -  Million Dollar View 2 BR
# 1   1 block to skytrain station, shops,restaurant,...
# 2                 Vancouver 4br 3ba house 20min to DT
# 3               Bright & Cheerful Uptown Garden Suite
# 4                  Downtown Yaletown Trendy 2 Bd/2Bth
# 5            Clean and Comfy, 2 Bd, Walk to the Drive
# 6                     Family friendly Point Grey Home
# 7                     A Real Gem in the Heart of Kits
# 8                 Stunning views, comfort, location!!
# 9        Close to downtown/shops/restaurants/skytrain
# 10  Adorable 2 Bedroom Cambie Craftsman - Garden S...
# 11                English Bay Hideaway @ Stanley Park
# 12                Kitsilano 2 bdrm Garden Level Suite
# 13                       The Garden Nook in Kitsilano
#
#                                           description  \
# 0   Stunning two bedroom, two bathroom apartment. ...
# 1   My place is close to bank, coffee shops, groce...
# 2   A newly renovated comfy and cozy family home i...
# 3   Welcome to our bright, cozy suite in the heart...
# 4   Large and bright corner unit of a brick concre...
# 5   This suite is close to vibrant Commercial Driv...
# 6   Family home suitable for short or long term st...
# 7   Modern looking, clean and comfortable renovate...
# 8   Gorgeous views and fabulous location. Availabl...
# 9   Prices depend on the length of the lease. 6 be...
# 10  One of the best homes in Vancouver!!  Fun fact...
# 11  The English Bay Hideaway is a two bedroom, two...
# 12  The perfect temporary home-away-from-home.  Fu...
# 13  Two bedrooms located in beautiful  Kitsilano, ...
#
#                                           picture_url  latitude  longitude  \
# 0   https://a0.muscache.com/pictures/55778229/c2f7...  49.28872 -123.12046
# 1   https://a0.muscache.com/pictures/82101/7127b63...  49.26339 -123.07145
# 2   https://a0.muscache.com/pictures/5ddc28c0-484f...  49.25277 -123.03774
# 3   https://a0.muscache.com/pictures/miso/Hosting-...  49.25636 -123.08636
# 4   https://a0.muscache.com/pictures/784805/089b1a...  49.27743 -123.11869
# 5   https://a0.muscache.com/pictures/731699/0abd40...  49.26758 -123.06016
# 6   https://a0.muscache.com/pictures/1192106/f3f7b...  49.25757 -123.18966
# 7   https://a0.muscache.com/pictures/37e3994b-4511...  49.27190 -123.15043
# 8   https://a0.muscache.com/pictures/21342517/ad2c...  49.29103 -123.05782
# 9   https://a0.muscache.com/pictures/c5dd03a6-7835...  49.26328 -123.07086
# 10  https://a0.muscache.com/pictures/6313540/76755...  49.25555 -123.11523
# 11  https://a0.muscache.com/pictures/15734766/2d63...  49.29178 -123.14175
# 12  https://a0.muscache.com/pictures/b45835fa-15ff...  49.25996 -123.16653
# 13  https://a0.muscache.com/pictures/11085034/87c4...  49.26213 -123.17482
#
#          property_type  accommodates  bedrooms  beds  \
# 0   Entire condominium             5       2.0   2.0
# 1         Entire house             6       3.0   4.0
# 2         Entire house             8       4.0   5.0
# 3   Entire guest suite             3       2.0   2.0
# 4   Entire condominium             4       2.0   2.0
# 5   Entire guest suite             3       2.0   2.0
# 6         Entire house             6       3.0   3.0
# 7     Entire apartment             4       2.0   2.0
# 8         Entire house             3       2.0   0.0
# 9         Entire house             7       3.0   3.0
# 10  Entire guest suite             4       2.0   2.0
# 11    Entire apartment             4       2.0   3.0
# 12  Entire guest suite             4       2.0   2.0
# 13  Entire guest suite             3       2.0   3.0
#
#                                             amenities  price  \
# 0   ["Iron", "Dryer", "Bed linens", "Cooking basic...  150.0
# 1   ["Heating", "Essentials", "Kitchen", "Iron", "...  100.0
# 2   ["Iron", "Dryer", "Bed linens", "Cooking basic...  130.0
# 3   ["Iron", "Dryer", "Bed linens", "Cooking basic...   69.0
# 4   ["Iron", "Hot tub", "Dryer", "Bed linens", "El...  132.0
# 5   ["Iron", "Dryer", "Cooking basics", "Hot water...  125.0
# 6   ["Iron", "Dryer", "Baby safety gates", "Bed li...  150.0
# 7   ["Iron", "Dryer", "Bed linens", "Cooking basic...  135.0
# 8   ["Iron", "Dryer", "Cooking basics", "Hot water...  100.0
# 9   ["Iron", "Dryer", "Cooking basics", "Hot water...  100.0
# 10  ["Dryer", "Cooking basics", "Hot water", "Dish...   90.0
# 11  ["Iron", "Ethernet connection", "Dryer", "Bed ...  130.0
# 12  ["Dryer", "Bed linens", "Cooking basics", "Hot...  125.0
# 13  ["Iron", "Dryer", "Bed linens", "Cooking basic...  114.0
#
#                                  num_amenities_nearby  len_dict
# 0   {'atm': 1, 'bank': 21, 'bar': 9, 'bicycle_rent...        15
# 1   {'bank': 5, 'bar': 1, 'bicycle_rental': 17, 'c...        11
# 2   {'bank': 2, 'cafe': 4, 'fast_food': 2, 'fuel':...         5
# 3   {'bank': 1, 'bar': 1, 'bicycle_rental': 12, 'c...        10
# 4   {'atm': 1, 'bank': 26, 'bar': 28, 'bicycle_ren...        16
# 5   {'bank': 6, 'bar': 2, 'bicycle_rental': 8, 'ca...        11
# 6   {'cafe': 5, 'fast_food': 2, 'pharmacy': 1, 'pu...         5
# 7   {'bank': 6, 'bicycle_rental': 16, 'cafe': 28, ...        12
# 8   {'bar': 1, 'bicycle_rental': 1, 'cafe': 3, 'fa...         7
# 9   {'bank': 5, 'bar': 1, 'bicycle_rental': 17, 'c...        11
# 10  {'bank': 7, 'bar': 1, 'bicycle_rental': 12, 'c...        12
# 11  {'bank': 6, 'bar': 3, 'bicycle_rental': 14, 'c...        11
# 12  {'bank': 3, 'cafe': 18, 'fast_food': 4, 'fuel'...         8
# 13  {'bank': 3, 'cafe': 20, 'fast_food': 8, 'fuel'...         8

# %%
len(listings_data_clean['num_amenities_nearby'][0])
# Out:
# 15

# %%
my_dict =  listings_data_clean['num_amenities_nearby'][4]
my_dict
# Out:
# {'atm': 1,
#  'bank': 26,
#  'bar': 28,
#  'bicycle_rental': 33,
#  'cafe': 124,
#  'car_rental': 5,
#  'car_sharing': 4,
#  'clinic': 5,
#  'fast_food': 133,
#  'fountain': 1,
#  'ice_cream': 4,
#  'pharmacy': 14,
#  'police': 1,
#  'pub': 26,
#  'restaurant': 186,
#  'theatre': 7}

# %%
my_dict['restaurant']
# Out:
# 196

# %%
len(my_dict)
# Out:
# 16

# %%
for key in my_dict:
    print(key)
# Out:
# atm
# bank
# bar
# bicycle_rental
# cafe
# car_rental
# car_sharing
# clinic
# fast_food
# fountain
# ice_cream
# pharmacy
# police
# pub
# restaurant
# theatre

# %%
restaurant, cafe, atm,car_rental, ice_cream, bus_station, pub, pharmacy
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-fe8ad1a0a52c> in <module>
# ----> 1 if my_dict['lol']:
#       2     print('hahah')
#
# KeyError: 'lol'

# %%
def ameneties_score(my_dict):
    
    num_different_amenities = len(my_dict)
    score = num_different_amenities * 10 
        
    for key in my_dict:
        if (my_dict[key] > 30):
            score+=30
        else:
            score+= my_dict[key]
    return score

# %%
ameneties_score(my_dict)
# Out:
# 402
